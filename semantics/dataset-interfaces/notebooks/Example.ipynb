# %% [markdown]
# # Dataset Interfaces Example Notebook
#
# In this notebook, we provide an example of creating a dataset interface for a subset of three classes of the ImageNet dataset. We also demonstrate how to create/load in a pre-trained text encoder containing our learred tokens for ImageNet* to generate your own counterfactual examples for ImageNet.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys

# comment this out if you are using the pip package
sys.path.append('../')

import torch
import matplotlib.pyplot as plt
from dataset_interfaces import utils
from dataset_interfaces import run_textual_inversion
from dataset_interfaces import generate
import dataset_interfaces.imagenet_utils as in_utils
import dataset_interfaces.inference_utils as infer_utils

# set root to ImageNet dataset
IMAGENET_ROOT = os.path.expandvars('$DSDIR/imagenet')
path_huggingface = os.path.expandvars('$DSDIR/HuggingFace_Models/')

# %% [markdown]
# To easily use the learned tokens in text prompts, we load the learned token-embedding pairs into a tokenizer and corresponding text encoder. Below we define the path where we will store the tokenizer and encoder.

# %%
# path where to store an encoder, which we will load in with the learned tokens
encoder_root = "../encoder_root"

# %% [markdown]
# ### Option 1: Construct Dataset Interface

# %%
# a subset of ImageNet classes
classes = [236, 651, 10]
class_names = [in_utils.IMAGENET_COMMON_CLASS_NAMES[c] for c in classes]
tokens = [f"<{class_names[i]}-{i}>" for i in range(len(class_names))]

train_data_dirs = [os.path.join(IMAGENET_ROOT, "train", in_utils.IMAGENET_IDX_TO_SYNSET[str(c)]['id']) for c in classes]

# %% [markdown]
# #### Run textual inversion

# %%
embeds = []
for i in range(len(classes)):
    print(i)
    # runs textual inversion on a single class
    embed = run_textual_inversion(train_data_dirs[i],
        token = tokens[i],
        class_name = class_names[i],
        pretrained_model_name_or_path=path_huggingface+"stabilityai/stable-diffusion-2"
    )
    
    embeds.append(embed)
# Out:
# Detected kernel version 4.18.0, which is below the recommended minimum of 5.5.0; this can cause the process to hang. It is recommended to upgrade the kernel to the minimum version or higher.
# 0
# You are resizing the embedding layer without providing a `pad_to_multiple_of` parameter. This means that the new embeding dimension will be 49409. This might induce some performance reduction as *Tensor Cores* will not be available. For more details  about this, or help on choosing the correct value for resizing, refer to this guide: https://docs.nvidia.com/deeplearning/performance/dl-performance-matrix-multiplication/index.html#requirements-tc
# You are resizing the embedding layer without providing a `pad_to_multiple_of` parameter. This means that the new embeding dimension will be 49410. This might induce some performance reduction as *Tensor Cores* will not be available. For more details  about this, or help on choosing the correct value for resizing, refer to this guide: https://docs.nvidia.com/deeplearning/performance/dl-performance-matrix-multiplication/index.html#requirements-tc
# /linkhome/rech/genone01/ulb98yg/.conda/envs/torch21/lib/python3.11/site-packages/diffusers/configuration_utils.py:244: FutureWarning: It is deprecated to pass a pretrained model name or path to `from_config`.If you were trying to load a scheduler, please use <class 'diffusers.schedulers.scheduling_ddpm.DDPMScheduler'>.from_pretrained(...) instead. Otherwise, please make sure to pass a configuration dictionary instead. This functionality will be removed in v1.0.0.
#   deprecate("config-passed-as-path", "1.0.0", deprecation_message, standard_warn=False)
#   0%|          | 0/3000 [00:00<?, ?it/s]

# %% [markdown]
# #### Add to tokenizer and text encoder

# %%
infer_utils.create_encoder(embeds=embeds, tokens=tokens, class_names=class_names, encoder_root=encoder_root)

# %% [markdown]
# ### Option 2: Create Encoder Root for ImageNet
# To use our learned tokens for the ImageNet (ImageNet*), we save a tokenizer and text encoder with the 1k tokens. This could take 6+ minutes

# %%
# # Get the tokens from huggingface
# !wget https://huggingface.co/datasets/madrylab/imagenet-star-tokens/resolve/main/tokens.zip
# !unzip tokens.zip

# %%
token_path = "../tokens"
infer_utils.create_imagenet_star_encoder(token_path, encoder_root="../encoder_root_imagenet", model_name=path_huggingface+"stabilityai/stable-diffusion-2")
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]You are resizing the embedding layer without providing a `pad_to_multiple_of` parameter. This means that the new embeding dimension will be 49409. This might induce some performance reduction as *Tensor Cores* will not be available. For more details  about this, or help on choosing the correct value for resizing, refer to this guide: https://docs.nvidia.com/deeplearning/performance/dl-performance-matrix-multiplication/index.html#requirements-tc
#   0%|          | 1/1000 [00:06<1:53:14,  6.80s/it]You are resizing the embedding layer without providing a `pad_to_multiple_of` parameter. This means that the new embeding dimension will be 49410. This might induce some performance reduction as *Tensor Cores* will not be available. For more details  about this, or help on choosing the correct value for resizing, refer to this guide: https://docs.nvidia.com/deeplearning/performance/dl-performance-matrix-multiplication/index.html#requirements-tc
#   0%|          | 2/1000 [00:13<1:53:01,  6.80s/it]You are resizing the embedding layer without providing a `pad_to_multiple_of` parameter. This means that the new embeding dimension will be 49411. This might induce some performance reduction as *Tensor Cores* will not be available. For more details  about this, or help on choosing the correct value for resizing, refer to this guide: https://docs.nvidia.com/deeplearning/performance/dl-performance-matrix-multiplication/index.html#requirements-tc
#   0%|          | 3/1000 [00:20<1:52:54,  6.80s/it]You are resizing the embedding layer without providing a `pad_to_multiple_of` parameter. This means that the new embeding dimension will be 49412. This might induce some performance reduction as *Tensor Cores* will not be available. For more details  about this, or help on choosing the correct value for resizing, refer to this guide: https://docs.nvidia.com/deeplearning/performance/dl-performance-matrix-multiplication/index.html#requirements-tc
#   0%|          | 4/1000 [00:27<1:52:51,  6.80s/it]You are resizing the embedding layer without providing a `pad_to_multiple_of` parameter. This means that the new embeding dimension will be 49413. This might induce some performance reduction as *Tensor Cores* will not be available. For more details  about this, or help on choosing the correct value for resizing, refer to this guide: https://docs.nvidia.com/deeplearning/performance/dl-performance-matrix-multiplication/index.html#requirements-tc
#   0%|          | 5/1000 [00:33<1:52:42,  6.80s/it]You are resizing the embedding layer without providing a `pad_to_multiple_of` parameter. This means that the new embeding dimension will be 49414. This might induce some performance reduction as *Tensor Cores* will not be available. For more details  about this, or help on choosing the correct value for resizing, refer to this guide: https://docs.nvidia.com/deeplearning/performance/dl-performance-matrix-multiplication/index.html#requirements-tc
#   1%|          | 6/1000 [00:40<1:52:31,  6.79s/it]You are resizing the embedding layer without providing a `pad_to_multiple_of` parameter. This means that the new embeding dimension will be 49415. This might induce some performance reduction as *Tensor Cores* will not be available. For more details  about this, or help on choosing the correct value for resizing, refer to this guide: https://docs.nvidia.com/deeplearning/performance/dl-performance-matrix-multiplication/index.html#requirements-tc
#   1%|          | 7/1000 [00:47<1:52:27,  6.79s/it]You are resizing the embedding layer without providing a `pad_to_multiple_of` parameter. This means that the new embeding dimension will be 49416. This might induce some performance reduction as *Tensor Cores* will not be available. For more details  about this, or help on choosing the correct value for resizing, refer to this guide: https://docs.nvidia.com/deeplearning/performance/dl-performance-matrix-multiplication/index.html#requirements-tc
#   1%|          | 8/1000 [00:54<1:52:20,  6.79s/it]You are resizing the embedding layer without providing a `pad_to_multiple_of` parameter. This means that the new embeding dimension will be 49417. This might induce some performance reduction as *Tensor Cores* will not be available. For more details  about this, or help on choosing the correct value for resizing, refer to this guide: https://docs.nvidia.com/deeplearning/performance/dl-performance-matrix-multiplication/index.html#requirements-tc
#   1%|          | 9/1000 [01:01<1:52:15,  6.80s/it]You are resizing the embedding layer without providing a `pad_to_multiple_of` parameter. This means that the new embeding dimension will be 49418. This might induce some performance reduction as *Tensor Cores* will not be available. For more details  about this, or help on choosing the correct value for resizing, refer to this guide: https://docs.nvidia.com/deeplearning/performance/dl-performance-matrix-multiplication/index.html#requirements-tc
#   1%|          | 10/1000 [01:07<1:52:15,  6.80s/it]You are resizing the embedding layer without providing a `pad_to_multiple_of` parameter. This means that the new embeding dimension will be 49419. This might induce some performance reduction as *Tensor Cores* will not be available. For more details  about this, or help on choosing the correct value for resizing, refer to this guide: https://docs.nvidia.com/deeplearning/performance/dl-performance-matrix-multiplication/index.html#requirements-tc
#   1%|          | 11/1000 [01:14<1:52:05,  6.80s/it]You are resizing the embedding layer without providing a `pad_to_multiple_of` parameter. This means that the new embeding dimension will be 49420. This might induce some performance reduction as *Tensor Cores* will not be available. For more details  about this, or help on choosing the correct value for resizing, refer to this guide: https://docs.nvidia.com/deeplearning/performance/dl-performance-matrix-multiplication/index.html#requirements-tc
#   1%|          | 12/1000 [01:21<1:51:56,  6.80s/it]You are resizing the embedding layer without providing a `pad_to_multiple_of` parameter. This means that the new embeding dimension will be 49421. This might induce some performance reduction as *Tensor Cores* will not be available. For more details  about this, or help on choosing the correct value for resizing, refer to this guide: https://docs.nvidia.com/deeplearning/performance/dl-performance-matrix-multiplication/index.html#requirements-tc
#   1%|▏         | 13/1000 [01:28<1:51:56,  6.81s/it]You are resizing the embedding layer without providing a `pad_to_multiple_of` parameter. This means that the new embeding dimension will be 
This might induce some performance reduction as *Tensor Cores* will not be available. For more details  about this, or help on choosing the correct value for resizing, refer to this guide: https://docs.nvidia.com/deeplearning/performance/dl-performance-matrix-multiplication/index.html#requirements-tc
#  98%|█████████▊| 981/1000 [1:52:31<02:11,  6.94s/it]You are resizing the embedding layer without providing a `pad_to_multiple_of` parameter. This means that the new embeding dimension will be 50390. This might induce some performance reduction as *Tensor Cores* will not be available. For more details  about this, or help on choosing the correct value for resizing, refer to this guide: https://docs.nvidia.com/deeplearning/performance/dl-performance-matrix-multiplication/index.html#requirements-tc
#  98%|█████████▊| 982/1000 [1:52:37<02:04,  6.94s/it]You are resizing the embedding layer without providing a `pad_to_multiple_of` parameter. This means that the new embeding dimension will be 50391. This might induce some performance reduction as *Tensor Cores* will not be available. For more details  about this, or help on choosing the correct value for resizing, refer to this guide: https://docs.nvidia.com/deeplearning/performance/dl-performance-matrix-multiplication/index.html#requirements-tc
#  98%|█████████▊| 983/1000 [1:52:44<01:57,  6.93s/it]You are resizing the embedding layer without providing a `pad_to_multiple_of` parameter. This means that the new embeding dimension will be 50392. This might induce some performance reduction as *Tensor Cores* will not be available. For more details  about this, or help on choosing the correct value for resizing, refer to this guide: https://docs.nvidia.com/deeplearning/performance/dl-performance-matrix-multiplication/index.html#requirements-tc
#  98%|█████████▊| 984/1000 [1:52:51<01:51,  6.94s/it]You are resizing the embedding layer without providing a `pad_to_multiple_of` parameter. This means that the new embeding dimension will be 50393. This might induce some performance reduction as *Tensor Cores* will not be available. For more details  about this, or help on choosing the correct value for resizing, refer to this guide: https://docs.nvidia.com/deeplearning/performance/dl-performance-matrix-multiplication/index.html#requirements-tc
#  98%|█████████▊| 985/1000 [1:52:58<01:44,  6.94s/it]You are resizing the embedding layer without providing a `pad_to_multiple_of` parameter. This means that the new embeding dimension will be 50394. This might induce some performance reduction as *Tensor Cores* will not be available. For more details  about this, or help on choosing the correct value for resizing, refer to this guide: https://docs.nvidia.com/deeplearning/performance/dl-performance-matrix-multiplication/index.html#requirements-tc
#  99%|█████████▊| 986/1000 [1:53:05<01:37,  6.97s/it]You are resizing the embedding layer without providing a `pad_to_multiple_of` parameter. This means that the new embeding dimension will be 50395. This might induce some performance reduction as *Tensor Cores* will not be available. For more details  about this, or help on choosing the correct value for resizing, refer to this guide: https://docs.nvidia.com/deeplearning/performance/dl-performance-matrix-multiplication/index.html#requirements-tc
#  99%|█████████▊| 987/1000 [1:53:12<01:30,  6.96s/it]You are resizing the embedding layer without providing a `pad_to_multiple_of` parameter. This means that the new embeding dimension will be 50396. This might induce some performance reduction as *Tensor Cores* will not be available. For more details  about this, or help on choosing the correct value for resizing, refer to this guide: https://docs.nvidia.com/deeplearning/performance/dl-performance-matrix-multiplication/index.html#requirements-tc
#  99%|█████████▉| 988/1000 [1:53:19<01:23,  6.96s/it]You are resizing the embedding layer without providing a `pad_to_multiple_of` parameter. This means that the new embeding dimension will be 50397. This might induce some performance reduction as *Tensor Cores* will not be available. For more details  about this, or help on choosing the correct value for resizing, refer to this guide: https://docs.nvidia.com/deeplearning/performance/dl-performance-matrix-multiplication/index.html#requirements-tc
#  99%|█████████▉| 989/1000 [1:53:26<01:16,  6.94s/it]You are resizing the embedding layer without providing a `pad_to_multiple_of` parameter. This means that the new embeding dimension will be 50398. This might induce some performance reduction as *Tensor Cores* will not be available. For more details  about this, or help on choosing the correct value for resizing, refer to this guide: https://docs.nvidia.com/deeplearning/performance/dl-performance-matrix-multiplication/index.html#requirements-tc
#  99%|█████████▉| 990/1000 [1:53:33<01:09,  6.94s/it]You are resizing the embedding layer without providing a `pad_to_multiple_of` parameter. This means that the new embeding dimension will be 50399. This might induce some performance reduction as *Tensor Cores* will not be available. For more details  about this, or help on choosing the correct value for resizing, refer to this guide: https://docs.nvidia.com/deeplearning/performance/dl-performance-matrix-multiplication/index.html#requirements-tc
#  99%|█████████▉| 991/1000 [1:53:40<01:02,  6.94s/it]You are resizing the embedding layer without providing a `pad_to_multiple_of` parameter. This means that the new embeding dimension will be 50400. This might induce some performance reduction as *Tensor Cores* will not be available. For more details  about this, or help on choosing the correct value for resizing, refer to this guide: https://docs.nvidia.com/deeplearning/performance/dl-performance-matrix-multiplication/index.html#requirements-tc
#  99%|█████████▉| 992/1000 [1:53:47<00:55,  6.94s/it]You are resizing the embedding layer without providing a `pad_to_multiple_of` parameter. This means that the new embeding dimension will be 50401. This might induce some performance reduction as *Tensor Cores* will not be available. For more details  about this, or help on choosing the correct value for resizing, refer to this guide: https://docs.nvidia.com/deeplearning/performance/dl-performance-matrix-multiplication/index.html#requirements-tc
#  99%|█████████▉| 993/1000 [1:53:54<00:48,  6.97s/it]You are resizing the embedding layer without providing a `pad_to_multiple_of` parameter. This means that the new embeding dimension will be 50402. This might induce some performance reduction as *Tensor Cores* will not be available. For more details  about this, or help on choosing the correct value for resizing, refer to this guide: https://docs.nvidia.com/deeplearning/performance/dl-performance-matrix-multiplication/index.html#requirements-tc
#  99%|█████████▉| 994/1000 [1:54:01<00:41,  6.96s/it]You are resizing the embedding layer without providing a `pad_to_multiple_of` parameter. This means that the new embeding dimension will be 50403. This might induce some performance reduction as *Tensor Cores* will not be available. For more details  about this, or help on choosing the correct value for resizing, refer to this guide: https://docs.nvidia.com/deeplearning/performance/dl-performance-matrix-multiplication/index.html#requirements-tc
# 100%|█████████▉| 995/1000 [1:54:08<00:34,  6.94s/it]You are resizing the embedding layer without providing a `pad_to_multiple_of` parameter. This means that the new embeding dimension will be 50404. This might induce some performance reduction as *Tensor Cores* will not be available. For more details  about this, or help on choosing the correct value for resizing, refer to this guide: https://docs.nvidia.com/deeplearning/performance/dl-performance-matrix-multiplication/index.html#requirements-tc
# 100%|█████████▉| 996/1000 [1:54:15<00:27,  6.94s/it]You are resizing the embedding layer without providing a `pad_to_multiple_of` parameter. This means that the new embeding dimension will be 50405. This might induce some performance reduction as *Tensor Cores* will not be available. For more details  about this, or help on choosing the correct value for resizing, refer to this guide: https://docs.nvidia.com/deeplearning/performance/dl-performance-matrix-multiplication/index.html#requirements-tc
# 100%|█████████▉| 997/1000 [1:54:22<00:20,  6.94s/it]You are resizing the embedding layer without providing a `pad_to_multiple_of` parameter. This means that the new embeding dimension will be 50406. This might induce some performance reduction as *Tensor Cores* will not be available. For more details  about this, or help on choosing the correct value for resizing, refer to this guide: https://docs.nvidia.com/deeplearning/performance/dl-performance-matrix-multiplication/index.html#requirements-tc
# 100%|█████████▉| 998/1000 [1:54:29<00:13,  6.94s/it]You are resizing the embedding layer without providing a `pad_to_multiple_of` parameter. This means that the new embeding dimension will be 50407. This might induce some performance reduction as *Tensor Cores* will not be available. For more details  about this, or help on choosing the correct value for resizing, refer to this guide: https://docs.nvidia.com/deeplearning/performance/dl-performance-matrix-multiplication/index.html#requirements-tc
# 100%|█████████▉| 999/1000 [1:54:36<00:06,  6.93s/it]You are resizing the embedding layer without providing a `pad_to_multiple_of` parameter. This means that the new embeding dimension will be 50408. This might induce some performance reduction as *Tensor Cores* will not be available. For more details  about this, or help on choosing the correct value for resizing, refer to this guide: https://docs.nvidia.com/deeplearning/performance/dl-performance-matrix-multiplication/index.html#requirements-tc
# 100%|██████████| 1000/1000 [1:54:43<00:00,  6.88s/it]

# %% [markdown]
# ### Generate Counterfactual Examples
#
# To use our learned class tokens for the ImageNet Dataset (ImageNet*), keep `use_provided=True` <br>
# To use the tokens learned in the cells above, set `use_provided=False`

# %%
use_provided = True

# %%
if use_provided:
    classes = [236, 651, 10]
    class_names = [in_utils.IMAGENET_COMMON_CLASS_NAMES[c] for c in classes]
    root = "./encoder_root_imagenet"

    
else:
    classes = [0, 1, 2]
    class_names = class_names
    root = encoder_root

# %% [markdown]
# #### A small set of distribution shifts, as examples

# %%
shifts = ["base", "in the grass", "in the snow", "in bright sunlight", "oil painting"]
prompts = [
    "a photo of a <TOKEN>",
    "a photo of a <TOKEN> in the grass",
    "a photo of a <TOKEN> in the snow",
    "a photo of a <TOKEN> in bright sunlight",
    "an oil painting of a <TOKEN>"
]

# %% [markdown]
# #### Generating counterfactual examples in the shifts above for each class

# %%
imgs = []
seed = 0
for c in classes:
    imgs_class = generate(root, c, prompts, num_samples=1, random_seed=range(seed, seed+len(prompts)))
    imgs_class = generate(root, c, prompts, num_samples=1, random_seed=range(seed, seed+len(prompts)))
    imgs_class = [imgs[0] for imgs in imgs_class]
    seed += len(prompts)
        
    imgs.append(imgs_class)

# %%
utils.visualize_samples(imgs, class_names, shifts, dpi=200, figsize=(6,4), fontsize=8)

# %% [markdown]
# ### CLIP Metrics
# To directly evaluate the quality of the generated image, we use CLIP similarity to quantify the presence of the object of interest and desired distribution shift in the image.

# %% [markdown]
# We can measure the extent to which generated images for the class "doberman" contain a doberman as follows:

# %%
infer_utils.clip_similarity(imgs[0], "a photo of a doberman")

# %% [markdown]
# We can measure the extent to which generated images in the grass are indeed in the grass as follows:

# %%
infer_utils.clip_similarity([imgs[i][1] for i in range(3)], "a photo in the grass")
